# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalTyagi2003/RL/blob/main/experiment2(part1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x= np.random.randint(0,50,1000)
y= x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82262845],
#        [0.82262845, 1.        ]])

# %%
plt.scatter (x,y)
plt.show()

# %% [markdown]
# Positive corelation between x and y shown in the scatter plot above

# %%
y= 100-(x + np.random.normal(0,10,1000))

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.80991879],
#        [-0.80991879,  1.        ]])

# %%
plt.scatter (x,y)
plt.show()

# %% [markdown]
# Negative corelation between x and y shown in the scatter plot above

# %%
x= np.random.randint(0,50,1000)
y= np.random.randint(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.01934086],
#        [-0.01934086,  1.        ]])

# %%
plt.scatter (x,y)
plt.show()

# %%
df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})

df['b'] = df['a']+ np.random.normal(0, 10, 1000)

df['c']= 100-df['a']+ np.random.normal(0, 50, 1000)

df ['d']= np.random.randint(0, 50, 1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.823013 -0.271897  0.048662
# b  0.823013  1.000000 -0.199102  0.032049
# c -0.271897 -0.199102  1.000000  0.030353
# d  0.048662  0.032049  0.030353  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, sort_ascending=False, figscale=1):
#   from matplotlib import pyplot as plt
#   figsize = (8 * figscale, 4 * figscale)
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['a'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
pd.plotting.scatter_matrix(df,figsize=[6,6])
plt.show()

# %%
plt.matshow(df.corr())

plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
